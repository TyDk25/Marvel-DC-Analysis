# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("db.csv", encoding='latin1')
df
# Out:
#     Unnamed: 0                       Original Title Company  Rate  Metascore  \
# 0            1                             Iron Man  Marvel   7.9         79
# 1            2                  The Incredible Hulk  Marvel   6.7         61
# 2            3                           Iron Man 2  Marvel   7.0         57
# 3            4                                 Thor  Marvel   7.0         57
# 4            5   Captain America: The First Avenger  Marvel   6.9         66
# 5            6                         The Avengers  Marvel   8.0         69
# 6            7                       Iron Man Three  Marvel   7.2         62
# 7            8                 Thor: The Dark World  Marvel   6.9         54
# 8            9  Captain America: The Winter Soldier  Marvel   7.7         70
# 9           10              Guardians of the Galaxy  Marvel   8.0         76
# 10          11             Avengers: Age of Ultron   Marvel   7.3         66
# ...

# %%
del df["Unnamed: 0"]

# %%
df["Original Title"].replace("Thor:Ragnarok", "Thor: Ragnarok", inplace=True)
df["Original Title"].replace("Captain Marve", "Captain Marvel", inplace=True)

# %%
Marvel = df[df["Company"].str.contains("Marvel")]

DC = df[df["Company"].str.contains("DC")]

# %%
df[["Rate"]].sort_values(by="Rate",ascending=False).head(10).plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='Original Title'>

# %%
Marvel["Rate"].mean()
# Out:
# 7.478260869565218

# %%
DC["Rate"].mean()
# Out:
# 6.80625

# %%
MarvelPre2016=Marvel[(Marvel["Release"]<2016)]

MarvelPre2016["Rate"].mean()
# Out:
# 7.324999999999999

# %%
MarvelPost2016=Marvel[(Marvel["Release"]>2016)]

MarvelPost2016["Rate"].mean()
# Out:
# 7.644444444444444

# %%
DCPre2016 = DC[(DC["Release"]<2016)]

DCPost2016 = DC[(DC["Release"]>2016)]

# %%
DCPre2016["Rate"].mean()
# Out:
# 6.644444444444445

# %%
DCPost2016["Rate"].mean()
# Out:
# 7.3199999999999985

# %%
Marvel[["Rate","Budget"]].sort_values(by="Budget", ascending=False).plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='Original Title'>

# %%
DC[["Rate","Budget"]].sort_values(by="Budget", ascending=False).plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='Original Title'>

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9         79     126     2008
# The Incredible Hulk                  Marvel   6.7         61    112      2008
# Iron Man 2                           Marvel   7.0         57    124      2010
# Thor                                 Marvel   7.0         57     115     2011
# Captain America: The First Avenger   Marvel   6.9         66     124     2011
# The Avengers                         Marvel   8.0         69     143     2012
# Iron Man Three                       Marvel   7.2         62     130     2013
# Thor: The Dark World                 Marvel   6.9         54     112     2013
# Captain America: The Winter Soldier  Marvel   7.7         70     136     2014
# Guardians of the Galaxy              Marvel   8.0         76     121     2014
# Avengers: Age of Ultron              Marvel   7.3         66     141     2015
# ...

# %%
rowindex=df.index[[2,7,8,16,19,22,26,14,18,21,10]]
trilogy = df.index[[6,12,16,21,30]]

# %%
df.iloc[16]
# Out:
# Company                   Marvel
# Rate                         7.9
# Metascore                     74
# Minutes                      130
# Release                     2017
# Budget                 180000000
# Opening Weekend USA    122744989
# Gross USA              315058289
# Gross Worldwide        853977126
# Name: Thor: Ragnarok, dtype: object

# %%
df.loc[rowindex, 'Sequels'] = "Sequel"
df.loc[trilogy,'Trilogy'] = "TRILOGY"
df["Sequels"]
# Out:
# Original Title
# Iron Man                                  NaN
# The Incredible Hulk                       NaN
# Iron Man 2                             Sequel
# Thor                                      NaN
# Captain America: The First Avenger        NaN
# The Avengers                              NaN
# Iron Man Three                            NaN
# Thor: The Dark World                   Sequel
# Captain America: The Winter Soldier    Sequel
# Guardians of the Galaxy                   NaN
# Avengers: Age of Ultron                Sequel
# Ant-Man                                   NaN
# Captain America: Civil War                NaN
# Doctor Strange                            NaN
# Guardians of the Galaxy Vol. 2         Sequel
# Spider-Man: Homecoming                    NaN
# Thor: Ragnarok                         Sequel
# Black Panther                             NaN
# Avengers: Infinity War                 Sequel
# Ant-Man and the Wasp                   Sequel
# ...

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9         79     126     2008
# The Incredible Hulk                  Marvel   6.7         61    112      2008
# Iron Man 2                           Marvel   7.0         57    124      2010
# Thor                                 Marvel   7.0         57     115     2011
# Captain America: The First Avenger   Marvel   6.9         66     124     2011
# The Avengers                         Marvel   8.0         69     143     2012
# Iron Man Three                       Marvel   7.2         62     130     2013
# Thor: The Dark World                 Marvel   6.9         54     112     2013
# Captain America: The Winter Soldier  Marvel   7.7         70     136     2014
# Guardians of the Galaxy              Marvel   8.0         76     121     2014
# Avengers: Age of Ultron              Marvel   7.3         66     141     2015
# ...

# %%
groupindex=df.index[[5,9,10,14,18,21,32,35]]
df.loc[groupindex,'Grouped Movies'] = "GROUPED"

# %%
df["Sequels"].fillna("First Movie", inplace=True)

# %%
df["Grouped Movies"].fillna("Not a Group", inplace=True)

# %%
df["Trilogy"].fillna("Not a Trilogy", inplace=True)

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9         79     126     2008
# The Incredible Hulk                  Marvel   6.7         61    112      2008
# Iron Man 2                           Marvel   7.0         57    124      2010
# Thor                                 Marvel   7.0         57     115     2011
# Captain America: The First Avenger   Marvel   6.9         66     124     2011
# The Avengers                         Marvel   8.0         69     143     2012
# Iron Man Three                       Marvel   7.2         62     130     2013
# Thor: The Dark World                 Marvel   6.9         54     112     2013
# Captain America: The Winter Soldier  Marvel   7.7         70     136     2014
# Guardians of the Galaxy              Marvel   8.0         76     121     2014
# Avengers: Age of Ultron              Marvel   7.3         66     141     2015
# ...

# %%
df[df["Sequels"].str.contains("Sequel")]["Rate"].mean()
# Out:
# 7.736363636363635

# %%
df[df["Sequels"].str.contains("First Movie")]["Rate"].mean()
# Out:
# 6.992857142857142

# %%
df[["Budget", "Gross Worldwide"]]
# Out:
#                                          Budget  Gross Worldwide
# Original Title
# Iron Man                              140000000        585366247
# The Incredible Hulk                   150000000        263427551
# Iron Man 2                            200000000        623933331
# Thor                                 150000000         449326618
# Captain America: The First Avenger    140000000        370569774
# The Avengers                          220000000       1518812988
# Iron Man Three                       200000000        1214811252
# Thor: The Dark World                  170000000        644783140
# Captain America: The Winter Soldier   170000000        714421503
# Guardians of the Galaxy               170000000        772776600
# Avengers: Age of Ultron               250000000       1402805868
# Ant-Man                               130000000        519311965
# Captain America: Civil War            250000000       1153296293
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, Iron Man to Joker
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company              39 non-null     object
#  1   Rate                 39 non-null     float64
#  2   Metascore            39 non-null     int64
#  3   Minutes              39 non-null     object
#  4   Release              39 non-null     int64
#  5   Budget               39 non-null     object
#  6   Opening Weekend USA  39 non-null     int64
#  7   Gross USA            39 non-null     int64
#  8   Gross Worldwide      39 non-null     int64
#  9   Sequels              39 non-null     object
#  10  Trilogy              39 non-null     object
#  11  Grouped Movies       39 non-null     object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 5.0+ KB

# %%
df["Budget"] = pd.to_numeric(df["Budget"], errors='coerce')

# %%
df[["Gross Worldwide","Budget"]].sort_values(by="Gross Worldwide", ascending=False)
# Out:
#                                      Gross Worldwide       Budget
# Original Title
# Avengers: Endgame                         2797800564  356000000.0
# Avengers: Infinity War                    2048359754          NaN
# The Avengers                              1518812988  220000000.0
# Avengers: Age of Ultron                   1402805868  250000000.0
# Black Panther                             1346913161  200000000.0
# Iron Man Three                            1214811252          NaN
# Captain America: Civil War                1153296293  250000000.0
# Aquaman                                   1148161807  160000000.0
# Spider-Man: Far from Home                 1131927996  160000000.0
# Captain Marvel                            1128274794          NaN
# The Dark Knight Rises                     1081041287  250000000.0
# Joker                                     1060504580          NaN
# The Dark Knight                           1004934033  185000000.0
# ...

# %%
df.at['Joker', 'Budget'] = 55000000
df.at['Jonah Hex', 'Budget'] = 47000000

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9       79.0     126   2008.0
# The Incredible Hulk                  Marvel   6.7       61.0    112    2008.0
# Iron Man 2                           Marvel   7.0       57.0    124    2010.0
# Thor                                 Marvel   7.0       57.0     115   2011.0
# Captain America: The First Avenger   Marvel   6.9       66.0     124   2011.0
# The Avengers                         Marvel   8.0       69.0     143   2012.0
# Iron Man Three                       Marvel   7.2       62.0     130   2013.0
# Thor: The Dark World                 Marvel   6.9       54.0     112   2013.0
# Captain America: The Winter Soldier  Marvel   7.7       70.0     136   2014.0
# Guardians of the Galaxy              Marvel   8.0       76.0     121   2014.0
# Avengers: Age of Ultron              Marvel   7.3       66.0     141   2015.0
# ...

# %%
df.at['Jonah Hex', 'Budget'] = 47000000

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9       79.0     126   2008.0
# The Incredible Hulk                  Marvel   6.7       61.0    112    2008.0
# Iron Man 2                           Marvel   7.0       57.0    124    2010.0
# Thor                                 Marvel   7.0       57.0     115   2011.0
# Captain America: The First Avenger   Marvel   6.9       66.0     124   2011.0
# The Avengers                         Marvel   8.0       69.0     143   2012.0
# Iron Man Three                       Marvel   7.2       62.0     130   2013.0
# Thor: The Dark World                 Marvel   6.9       54.0     112   2013.0
# Captain America: The Winter Soldier  Marvel   7.7       70.0     136   2014.0
# Guardians of the Galaxy              Marvel   8.0       76.0     121   2014.0
# Avengers: Age of Ultron              Marvel   7.3       66.0     141   2015.0
# ...

# %%
df.loc['Jonah Hex', 'Budget'] = 99

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9       79.0     126   2008.0
# The Incredible Hulk                  Marvel   6.7       61.0    112    2008.0
# Iron Man 2                           Marvel   7.0       57.0    124    2010.0
# Thor                                 Marvel   7.0       57.0     115   2011.0
# Captain America: The First Avenger   Marvel   6.9       66.0     124   2011.0
# The Avengers                         Marvel   8.0       69.0     143   2012.0
# Iron Man Three                       Marvel   7.2       62.0     130   2013.0
# Thor: The Dark World                 Marvel   6.9       54.0     112   2013.0
# Captain America: The Winter Soldier  Marvel   7.7       70.0     136   2014.0
# Guardians of the Galaxy              Marvel   8.0       76.0     121   2014.0
# Avengers: Age of Ultron              Marvel   7.3       66.0     141   2015.0
# ...

# %%
del df.loc['row2']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 del df.loc['row2']
#
# AttributeError: __delitem__

# %%
df.drop('Jonah Hex\t', inplace=True)

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9       79.0     126   2008.0
# The Incredible Hulk                  Marvel   6.7       61.0    112    2008.0
# Iron Man 2                           Marvel   7.0       57.0    124    2010.0
# Thor                                 Marvel   7.0       57.0     115   2011.0
# Captain America: The First Avenger   Marvel   6.9       66.0     124   2011.0
# The Avengers                         Marvel   8.0       69.0     143   2012.0
# Iron Man Three                       Marvel   7.2       62.0     130   2013.0
# Thor: The Dark World                 Marvel   6.9       54.0     112   2013.0
# Captain America: The Winter Soldier  Marvel   7.7       70.0     136   2014.0
# Guardians of the Galaxy              Marvel   8.0       76.0     121   2014.0
# Avengers: Age of Ultron              Marvel   7.3       66.0     141   2015.0
# ...

# %%
df.at['Iron Man Three', 'Budget'] = 200000000

# %%
df.at['Thor','Budget'] = 150000000

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9       79.0     126   2008.0
# The Incredible Hulk                  Marvel   6.7       61.0    112    2008.0
# Iron Man 2                           Marvel   7.0       57.0    124    2010.0
# Thor                                 Marvel   7.0       57.0     115   2011.0
# Captain America: The First Avenger   Marvel   6.9       66.0     124   2011.0
# The Avengers                         Marvel   8.0       69.0     143   2012.0
# Iron Man Three                       Marvel   7.2       62.0     130   2013.0
# Thor: The Dark World                 Marvel   6.9       54.0     112   2013.0
# Captain America: The Winter Soldier  Marvel   7.7       70.0     136   2014.0
# Guardians of the Galaxy              Marvel   8.0       76.0     121   2014.0
# Avengers: Age of Ultron              Marvel   7.3       66.0     141   2015.0
# ...

# %%
df.at['Spider-Man: Homecoming','Budget'] = 175000000

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9       79.0     126   2008.0
# The Incredible Hulk                  Marvel   6.7       61.0    112    2008.0
# Iron Man 2                           Marvel   7.0       57.0    124    2010.0
# Thor                                 Marvel   7.0       57.0     115   2011.0
# Captain America: The First Avenger   Marvel   6.9       66.0     124   2011.0
# The Avengers                         Marvel   8.0       69.0     143   2012.0
# Iron Man Three                       Marvel   7.2       62.0     130   2013.0
# Thor: The Dark World                 Marvel   6.9       54.0     112   2013.0
# Captain America: The Winter Soldier  Marvel   7.7       70.0     136   2014.0
# Guardians of the Galaxy              Marvel   8.0       76.0     121   2014.0
# Avengers: Age of Ultron              Marvel   7.3       66.0     141   2015.0
# ...

# %%
df.at['Avengers: Infinity War', 'Budget'] = 321000000

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9       79.0     126   2008.0
# The Incredible Hulk                  Marvel   6.7       61.0    112    2008.0
# Iron Man 2                           Marvel   7.0       57.0    124    2010.0
# Thor                                 Marvel   7.0       57.0     115   2011.0
# Captain America: The First Avenger   Marvel   6.9       66.0     124   2011.0
# The Avengers                         Marvel   8.0       69.0     143   2012.0
# Iron Man Three                       Marvel   7.2       62.0     130   2013.0
# Thor: The Dark World                 Marvel   6.9       54.0     112   2013.0
# Captain America: The Winter Soldier  Marvel   7.7       70.0     136   2014.0
# Guardians of the Galaxy              Marvel   8.0       76.0     121   2014.0
# Avengers: Age of Ultron              Marvel   7.3       66.0     141   2015.0
# ...

# %%
df.at['Captain Marvel', 'Budget'] = 175000000

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9       79.0     126   2008.0
# The Incredible Hulk                  Marvel   6.7       61.0    112    2008.0
# Iron Man 2                           Marvel   7.0       57.0    124    2010.0
# Thor                                 Marvel   7.0       57.0     115   2011.0
# Captain America: The First Avenger   Marvel   6.9       66.0     124   2011.0
# The Avengers                         Marvel   8.0       69.0     143   2012.0
# Iron Man Three                       Marvel   7.2       62.0     130   2013.0
# Thor: The Dark World                 Marvel   6.9       54.0     112   2013.0
# Captain America: The Winter Soldier  Marvel   7.7       70.0     136   2014.0
# Guardians of the Galaxy              Marvel   8.0       76.0     121   2014.0
# Avengers: Age of Ultron              Marvel   7.3       66.0     141   2015.0
# ...

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9       79.0     126   2008.0
# The Incredible Hulk                  Marvel   6.7       61.0    112    2008.0
# Iron Man 2                           Marvel   7.0       57.0    124    2010.0
# Thor                                 Marvel   7.0       57.0     115   2011.0
# Captain America: The First Avenger   Marvel   6.9       66.0     124   2011.0
# The Avengers                         Marvel   8.0       69.0     143   2012.0
# Iron Man Three                       Marvel   7.2       62.0     130   2013.0
# Thor: The Dark World                 Marvel   6.9       54.0     112   2013.0
# Captain America: The Winter Soldier  Marvel   7.7       70.0     136   2014.0
# Guardians of the Galaxy              Marvel   8.0       76.0     121   2014.0
# Avengers: Age of Ultron              Marvel   7.3       66.0     141   2015.0
# ...

# %%
df.at['Jonah Hex', 'Company'] = 'DC'

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9       79.0     126   2008.0
# The Incredible Hulk                  Marvel   6.7       61.0    112    2008.0
# Iron Man 2                           Marvel   7.0       57.0    124    2010.0
# Thor                                 Marvel   7.0       57.0     115   2011.0
# Captain America: The First Avenger   Marvel   6.9       66.0     124   2011.0
# The Avengers                         Marvel   8.0       69.0     143   2012.0
# Iron Man Three                       Marvel   7.2       62.0     130   2013.0
# Thor: The Dark World                 Marvel   6.9       54.0     112   2013.0
# Captain America: The Winter Soldier  Marvel   7.7       70.0     136   2014.0
# Guardians of the Galaxy              Marvel   8.0       76.0     121   2014.0
# Avengers: Age of Ultron              Marvel   7.3       66.0     141   2015.0
# ...

# %%
df.at['Jonah Hex', 'Rate'] = 4.7

# %%
df.at['Jonah Hex', 'Metascore'] = 33.0

# %%
df.at['Jonah Hex', 'Minutes'] = 81

# %%
df.at['Jonah Hex', 'Release'] = 2010.0

# %%
df.at['Jonah Hex','Budget'] = 47000000

# %%
df.at['Jonah Hex','Opening Weekend USA'] = 5379365.0

# %%
df.at['Jonah Hex', 'Gross USA'] = 10547117.0

# %%
df.at['Jonah Hex', 'Gross USA'] = 1

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9       79.0     126   2008.0
# The Incredible Hulk                  Marvel   6.7       61.0    112    2008.0
# Iron Man 2                           Marvel   7.0       57.0    124    2010.0
# Thor                                 Marvel   7.0       57.0     115   2011.0
# Captain America: The First Avenger   Marvel   6.9       66.0     124   2011.0
# The Avengers                         Marvel   8.0       69.0     143   2012.0
# Iron Man Three                       Marvel   7.2       62.0     130   2013.0
# Thor: The Dark World                 Marvel   6.9       54.0     112   2013.0
# Captain America: The Winter Soldier  Marvel   7.7       70.0     136   2014.0
# Guardians of the Galaxy              Marvel   8.0       76.0     121   2014.0
# Avengers: Age of Ultron              Marvel   7.3       66.0     141   2015.0
# ...

# %%
df.at['Jonah Hex', 'Gross Worldwide'] = 1.090331e+07

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9       79.0     126   2008.0
# The Incredible Hulk                  Marvel   6.7       61.0    112    2008.0
# Iron Man 2                           Marvel   7.0       57.0    124    2010.0
# Thor                                 Marvel   7.0       57.0     115   2011.0
# Captain America: The First Avenger   Marvel   6.9       66.0     124   2011.0
# The Avengers                         Marvel   8.0       69.0     143   2012.0
# Iron Man Three                       Marvel   7.2       62.0     130   2013.0
# Thor: The Dark World                 Marvel   6.9       54.0     112   2013.0
# Captain America: The Winter Soldier  Marvel   7.7       70.0     136   2014.0
# Guardians of the Galaxy              Marvel   8.0       76.0     121   2014.0
# Avengers: Age of Ultron              Marvel   7.3       66.0     141   2015.0
# ...

# %%
df.at['Jonah Hex', 'Sequels'] = 'First Movie'

# %%
df.at['Jonah Hex', 'Trilogy'] = 'Not a Trilogy'

# %%
df.at['Jonah Hex', 'Grouped Movies'] = 'Not a Group'

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9       79.0     126   2008.0
# The Incredible Hulk                  Marvel   6.7       61.0    112    2008.0
# Iron Man 2                           Marvel   7.0       57.0    124    2010.0
# Thor                                 Marvel   7.0       57.0     115   2011.0
# Captain America: The First Avenger   Marvel   6.9       66.0     124   2011.0
# The Avengers                         Marvel   8.0       69.0     143   2012.0
# Iron Man Three                       Marvel   7.2       62.0     130   2013.0
# Thor: The Dark World                 Marvel   6.9       54.0     112   2013.0
# Captain America: The Winter Soldier  Marvel   7.7       70.0     136   2014.0
# Guardians of the Galaxy              Marvel   8.0       76.0     121   2014.0
# Avengers: Age of Ultron              Marvel   7.3       66.0     141   2015.0
# ...

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9       79.0     126   2008.0
# The Incredible Hulk                  Marvel   6.7       61.0    112    2008.0
# Iron Man 2                           Marvel   7.0       57.0    124    2010.0
# Thor                                 Marvel   7.0       57.0     115   2011.0
# Captain America: The First Avenger   Marvel   6.9       66.0     124   2011.0
# The Avengers                         Marvel   8.0       69.0     143   2012.0
# Iron Man Three                       Marvel   7.2       62.0     130   2013.0
# Thor: The Dark World                 Marvel   6.9       54.0     112   2013.0
# Captain America: The Winter Soldier  Marvel   7.7       70.0     136   2014.0
# Guardians of the Galaxy              Marvel   8.0       76.0     121   2014.0
# Avengers: Age of Ultron              Marvel   7.3       66.0     141   2015.0
# ...

# %%
df.rename(columns={'Gross USA': 'Gross USA'}, inplace=True)

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9       79.0     126   2008.0
# The Incredible Hulk                  Marvel   6.7       61.0    112    2008.0
# Iron Man 2                           Marvel   7.0       57.0    124    2010.0
# Thor                                 Marvel   7.0       57.0     115   2011.0
# Captain America: The First Avenger   Marvel   6.9       66.0     124   2011.0
# The Avengers                         Marvel   8.0       69.0     143   2012.0
# Iron Man Three                       Marvel   7.2       62.0     130   2013.0
# Thor: The Dark World                 Marvel   6.9       54.0     112   2013.0
# Captain America: The Winter Soldier  Marvel   7.7       70.0     136   2014.0
# Guardians of the Galaxy              Marvel   8.0       76.0     121   2014.0
# Avengers: Age of Ultron              Marvel   7.3       66.0     141   2015.0
# ...

# %%
df.at['Jonah Hex', 'Gross USA'] = 1

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9       79.0     126   2008.0
# The Incredible Hulk                  Marvel   6.7       61.0    112    2008.0
# Iron Man 2                           Marvel   7.0       57.0    124    2010.0
# Thor                                 Marvel   7.0       57.0     115   2011.0
# Captain America: The First Avenger   Marvel   6.9       66.0     124   2011.0
# The Avengers                         Marvel   8.0       69.0     143   2012.0
# Iron Man Three                       Marvel   7.2       62.0     130   2013.0
# Thor: The Dark World                 Marvel   6.9       54.0     112   2013.0
# Captain America: The Winter Soldier  Marvel   7.7       70.0     136   2014.0
# Guardians of the Galaxy              Marvel   8.0       76.0     121   2014.0
# Avengers: Age of Ultron              Marvel   7.3       66.0     141   2015.0
# ...

# %%
df.columns.values[8] = 'Gross Worldwide'

# %%
df.columns.values[7] = 'Gross USA'

# %%
df.at['Jonah Hex', 'Gross USA'] = 'hey'

# %%
del df['Gross USA']

# %%
df.columns.values[7] = 'Gross US'

# %%
df.at['Jonah Hex', 'Gross US'] = 10547117.0

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel   7.9       79.0     126   2008.0
# The Incredible Hulk                  Marvel   6.7       61.0    112    2008.0
# Iron Man 2                           Marvel   7.0       57.0    124    2010.0
# Thor                                 Marvel   7.0       57.0     115   2011.0
# Captain America: The First Avenger   Marvel   6.9       66.0     124   2011.0
# The Avengers                         Marvel   8.0       69.0     143   2012.0
# Iron Man Three                       Marvel   7.2       62.0     130   2013.0
# Thor: The Dark World                 Marvel   6.9       54.0     112   2013.0
# Captain America: The Winter Soldier  Marvel   7.7       70.0     136   2014.0
# Guardians of the Galaxy              Marvel   8.0       76.0     121   2014.0
# Avengers: Age of Ultron              Marvel   7.3       66.0     141   2015.0
# ...

# %%
df.dropna(inplace=True)

# %%
pd.options.display.float_format = '{:.0f}'.format

# %%
df
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
# Iron Man                             Marvel     8         79     126     2008
# The Incredible Hulk                  Marvel     7         61    112      2008
# Iron Man 2                           Marvel     7         57    124      2010
# Thor                                 Marvel     7         57     115     2011
# Captain America: The First Avenger   Marvel     7         66     124     2011
# The Avengers                         Marvel     8         69     143     2012
# Iron Man Three                       Marvel     7         62     130     2013
# Thor: The Dark World                 Marvel     7         54     112     2013
# Captain America: The Winter Soldier  Marvel     8         70     136     2014
# Guardians of the Galaxy              Marvel     8         76     121     2014
# Avengers: Age of Ultron              Marvel     7         66     141     2015
# ...

# %%
df[["Rate"]].sort_values(by="Rate", ascending=False).head(5).plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='Original Title'>

# %%
df['Profit Worldwide'] = df['Gross Worldwide'] - df['Budget']

# %%
df.sort_values(by='Profit Worldwide', ascending=False)
# Out:
#                                     Company  Rate  Metascore Minutes  Release  \
# Original Title
#